# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv('/Users/michaelswift/Downloads/r_biotech salary and company survey - 2024.csv')

# Display the first few rows of the dataset

# %%
data.columns
# Out:
# Index(['Timestamp', 'What country do you work in?',
#        'Where is the closest major city or hub?', 'Where are you located?',
#        'Biotech sub industry?', 'Company or Institution Name',
#        'Company Details - public/private/start-up/ subsidiary of ',
#        'Company Detail - Approximate Company Size',
#        'Role / Title of current position', 'What degrees do you have? ',
#        'List other relevant and recognized certifications',
#        '[Optional] Briefly describe your position', 'Years of Experience',
#        'Compensation - Annual Base Salary/Pay', 'Compensation - Overtime Pay',
#        'Compensation - Annual Target Bonus ($)',
#        'Compensation - Annual Equity/Stock Option',
#        'Compensation - Most recent annual yearly raise (%)',
#        'Compensation - Sign on Bonus Value',
#        'Compensation - Sign on Stock/Equity Options',
#        'Compensation - Retirement Benefits (free text)',
# ...

# %%
data.groupby(['What degrees do you have? ', 'Years of Experience'])['Compensation - Annual Base Salary/Pay'].mean().xs('PhD or Equivalent')
# Out:
# Years of Experience
# 0     119607.407407
# 1     115242.744186
# 2     121706.684444
# 3     126295.312500
# 4     121692.142857
# 5     162142.978723
# 6     166320.909091
# 7     163387.096774
# 8     155318.181818
# 9     186923.076923
# 10    166512.142857
# 11    198454.545455
# 12    216200.000000
# 13    207000.000000
# 14    196000.000000
# 15    169018.333333
# 16    263000.000000
# 17    247400.000000
# 18    187736.666667
# 19    176000.000000
# 20    169403.000000
# 21    250000.000000
# 22    174000.000000
# 25    280000.000000
# 32    267000.000000
# Name: Compensation - Annual Base Salary/Pay, dtype: float64
